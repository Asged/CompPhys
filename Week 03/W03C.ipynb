# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist
from week03 import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import matplotlib.pyplot as plt
#       3 from scipy.spatial.distance import pdist
# ----> 4 from week03 import *
#
# ModuleNotFoundError: No module named 'week03'

# %%
calc = Morse()
class AtomicCluster (AtomicClusterBase2): # no changes needed
    pass
cluster = AtomicCluster (calc,pos=[[-0.5,0],[0,np.sqrt(3)/2],[0.5,0]],static=[True,False,True])
print(cluster.potential_energy)
